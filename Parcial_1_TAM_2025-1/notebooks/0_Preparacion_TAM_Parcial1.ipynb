# %% [markdown]
# <a href="https://colab.research.google.com/github/johanstevenbejarano/Teoria-de-Aprendizaje-Maquina/blob/main/Parcial_1_TAM_2025-1/notebooks/0_Preparacion_TAM_Parcial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Clonación del repositorio en entorno Colab
#
# Este bloque permite clonar el repositorio público del proyecto en caso de que el entorno de Colab se reinicie (lo cual borra todo el contenido local en `/content`).
# La línea de eliminación está comentada por defecto y solo debe activarse si el repositorio ya fue clonado previamente.

# %%
# === PREPARACIÓN DEL ENTORNO EN COLAB ===

# 1. Ir al directorio raíz
# %cd /content/

# 2. Eliminar repo si ya existe (descomentar solo si hay conflictos)
# !rm -rf Teoria-de-Aprendizaje-Maquina

# 3. Clonar repositorio desde GitHub (público)
# !git clone https://github.com/johanstevenbejarano/Teoria-de-Aprendizaje-Maquina.git

# 4. Ir a la carpeta del parcial
# %cd Teoria-de-Aprendizaje-Maquina/Parcial_1_TAM_2025-1/
# Out:
# /content
# Cloning into 'Teoria-de-Aprendizaje-Maquina'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 69 (delta 32), reused 32 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 3.54 MiB | 30.70 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/Teoria-de-Aprendizaje-Maquina/Parcial_1_TAM_2025-1

# %% [markdown]
# ### Descarga manual del dataset
#
# Para este proyecto se utiliza el dataset **Ames Housing Dataset**, disponible públicamente en Kaggle.
#
# 🔗 **Enlace oficial de descarga (requiere inicio de sesión en Kaggle):**
# https://www.kaggle.com/datasets/shashanknecrothapa/ames-housing-dataset
#
# Para evitar vulnerabilidades y el uso de claves privadas, **no se utiliza la API de Kaggle** (`kaggle.json`) en este proyecto.
# En su lugar, el usuario debe descargar manualmente el archivo `AmesHousing.csv` y cargarlo en Colab mediante la función `files.upload()`.
#
# Una vez subido, el archivo puede moverse a la carpeta `data/` para mantener el proyecto organizado.

# %%
from google.colab import files

# Subir manualmente el archivo descargado de Kaggle
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bc90053b-7ccc-45b7-a1b1-5a62e8545678" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc90053b-7ccc-45b7-a1b1-5a62e8545678">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Crear la carpeta si no existe
# !mkdir -p data/

# Mover el archivo subido a la carpeta correspondiente
# !mv AmesHousing.csv data/

# %%
import pandas as pd

# Leer el archivo desde la ruta organizada
df = pd.read_csv("data/AmesHousing.csv")

# Verificar las primeras filas
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %% [markdown]
# ✅ **Dataset cargado correctamente.**
#
# El archivo `AmesHousing.csv` se encuentra ahora en la carpeta `data/` y se ha verificado su lectura mediante `pandas`.
# Este archivo estará listo para su exploración, análisis y modelado en los siguientes pasos del proyecto.
