# %% [markdown]
# <a href="https://colab.research.google.com/github/johanstevenbejarano/Teoria-de-Aprendizaje-Maquina/blob/main/Teoria-de-Aprendizaje-Maquina/Parcial_1_TAM_2025-1/notebooks/0_Preparacion_TAM_Parcial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TITULO

# %% [markdown]
# ## Clonación del repositorio en entorno Colab
#
# Este bloque permite clonar el repositorio público del proyecto en caso de que el entorno de Colab se reinicie (lo cual borra todo el contenido local en `/content`).
# La línea de eliminación está comentada por defecto y solo debe activarse si el repositorio ya fue clonado previamente.

# %%
# === PREPARACIÓN DEL ENTORNO EN COLAB ===

# 1. Ir al directorio raíz
# %cd /content/

# 2. Eliminar repo si ya existe (descomentar solo si hay conflictos)
# !rm -rf Teoria-de-Aprendizaje-Maquina

# 3. Clonar repositorio desde GitHub (público)
# !git clone https://github.com/johanstevenbejarano/Teoria-de-Aprendizaje-Maquina.git

# 4. Ir a la carpeta del parcial
# %cd Teoria-de-Aprendizaje-Maquina/Parcial_1_TAM_2025-1/
# Out:
# /content
# Cloning into 'Teoria-de-Aprendizaje-Maquina'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 69 (delta 32), reused 32 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 3.54 MiB | 30.70 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/Teoria-de-Aprendizaje-Maquina/Parcial_1_TAM_2025-1

# %% [markdown]
# ## Descarga automática del dataset desde Google Drive (sin API)
#
# Con el fin de evitar el uso de la API de Kaggle y facilitar la reproducción del proyecto, el archivo `AmesHousing.csv` ha sido subido a Google Drive con acceso público.
# A continuación, se descarga automáticamente mediante `wget` y se mueve a la carpeta `data/`.
#
# 🔗 Enlace al dataset:
# https://drive.google.com/file/d/1T4KG81p_nJdf9CKOp278Wl8q1S8uyMCK/view?usp=sharing

# %%
# !pip install -q gdown

# %%
# === DESCARGA DIRECTA DE ARCHIVO PEQUEÑO DESDE GOOGLE DRIVE ===

file_id = "1T4KG81p_nJdf9CKOp278Wl8q1S8uyMCK"
file_name = "AmesHousing.csv"

# !gdown --id {file_id} --output {file_name}

# Crear carpeta y mover el archivo
# !mkdir -p data/
# !mv AmesHousing.csv data/
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1T4KG81p_nJdf9CKOp278Wl8q1S8uyMCK
# To: /content/Teoria-de-Aprendizaje-Maquina/Parcial_1_TAM_2025-1/AmesHousing.csv
# 100% 964k/964k [00:00<00:00, 20.6MB/s]

# %% [markdown]
# **El archivo `AmesHousing.csv` ha sido descargado correctamente desde Google Drive y ubicado en la carpeta `data/`.**
#
# A partir de este punto, se procederá con la exploración inicial del dataset (`EDA`) y su posterior validación y preparación para el modelado.

# %% [markdown]
# ## Revisión general del dataset
#
# El primer paso de la exploración consiste en comprender la estructura básica del conjunto de datos: número de filas y columnas, nombres de las variables, tipos de datos, y estadísticas descriptivas generales.
#
# Este diagnóstico inicial permitirá detectar posibles problemas como valores nulos, tipos de datos incorrectos, presencia de duplicados, o columnas irrelevantes para la tarea de aprendizaje supervisado.

# %%
import pandas as pd

# cARGAR Dataset
df = pd.read_csv("data/AmesHousing.csv")


# Dimensiones del dataset
print("Dimensiones del dataset:", df.shape)

# Nombres de columnas
print("\nColumnas del dataset:")
print(df.columns.tolist())
# Out:
# Dimensiones del dataset: (2930, 82)
#
# Columnas del dataset:
# ...

# %%
# Información general del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
# Estadísticas básicas
df.describe().T
# Out:
#                   count          mean           std          min  \
# Order            2930.0  1.465500e+03  8.459625e+02          1.0
# PID              2930.0  7.144645e+08  1.887308e+08  526301100.0
# MS SubClass      2930.0  5.738737e+01  4.263802e+01         20.0
# Lot Frontage     2440.0  6.922459e+01  2.336533e+01         21.0
# Lot Area         2930.0  1.014792e+04  7.880018e+03       1300.0
# Overall Qual     2930.0  6.094881e+00  1.411026e+00          1.0
# Overall Cond     2930.0  5.563140e+00  1.111537e+00          1.0
# Year Built       2930.0  1.971356e+03  3.024536e+01       1872.0
# Year Remod/Add   2930.0  1.984267e+03  2.086029e+01       1950.0
# Mas Vnr Area     2907.0  1.018968e+02  1.791126e+02          0.0
# BsmtFin SF 1     2929.0  4.426296e+02  4.555908e+02          0.0
# BsmtFin SF 2     2929.0  4.972243e+01  1.691685e+02          0.0
# Bsmt Unf SF      2929.0  5.592625e+02  4.394942e+02          0.0
# ...

# %%
# Ver cuántas variables categóricas hay
categorical_cols = df.select_dtypes(include=["object"]).columns.tolist()
print(f"\nVariables categóricas ({len(categorical_cols)}):", categorical_cols)

# Frecuencias para las primeras 5 columnas categóricas
for col in categorical_cols[:5]:
    print(f"\nFrecuencias de la variable '{col}':")
    print(df[col].value_counts(dropna=False).head())
# Out:
# Variables categóricas (43): ['MS Zoning', 'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC', 'Central Air', 'Electrical', 'Kitchen Qual', 'Functional', 'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature', 'Sale Type', 'Sale Condition']
#
# Frecuencias de la variable 'MS Zoning':
# MS Zoning
# RL         2273
# RM          462
# FV          139
# RH           27
# C (all)      25
# Name: count, dtype: int64
#
# Frecuencias de la variable 'Street':
# Street
# Pave    2918
# Grvl      12
# Name: count, dtype: int64
#
# Frecuencias de la variable 'Alley':
# Alley
# NaN     2732
# ...

# %%
# Conteo de valores nulos por columna
null_counts = df.isnull().sum()
null_counts = null_counts[null_counts > 0].sort_values(ascending=False)
print("\nColumnas con valores nulos:")
print(null_counts)
# Out:
# Columnas con valores nulos:
# Pool QC           2917
# Misc Feature      2824
# Alley             2732
# Fence             2358
# Mas Vnr Type      1775
# Fireplace Qu      1422
# Lot Frontage       490
# Garage Qual        159
# Garage Cond        159
# Garage Yr Blt      159
# Garage Finish      159
# Garage Type        157
# Bsmt Exposure       83
# BsmtFin Type 2      81
# Bsmt Cond           80
# Bsmt Qual           80
# BsmtFin Type 1      80
# Mas Vnr Area        23
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# BsmtFin SF 1         1
# BsmtFin SF 2         1
# Electrical           1
# Total Bsmt SF        1
# Bsmt Unf SF          1
# Garage Area          1
# Garage Cars          1
# dtype: int64

# %%
# Verificar si hay filas duplicadas
print("\nNúmero de filas duplicadas:", df.duplicated().sum())
# Out:
# Número de filas duplicadas: 0

# %% [markdown]
# **Cierre de la revisión inicial del dataset**
#
# Se completó la exploración general del dataset, identificando **82 variables** distribuidas en **43 categóricas** y **39 numéricas**.
# No se detectaron filas duplicadas. Varias columnas presentan valores nulos, en su mayoría asociados a la ausencia real de características (como piscina, chimenea, callejón, etc.), lo cual requerirá tratamiento contextual más adelante.
#
# Entre las variables numéricas se encuentran medidas continuas (áreas, años, conteos) y la variable objetivo `SalePrice`. Sin embargo, algunas variables numéricas representan códigos o categorías discretas (`MS SubClass`, `Mo Sold`, `Yr Sold`) y otras funcionan como identificadores (`PID`, `Order`), por lo que su uso será evaluado cuidadosamente en las siguientes etapas.
#
# Este diagnóstico inicial proporciona el inicio para las decisiones de limpieza, transformación y selección de variables que se abordarán en las fases posteriores de preprocesamiento e ingeniería de características.
